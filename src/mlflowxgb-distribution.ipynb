# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, log_loss
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt
import matplotlib as mpl

import mlflow 
import pandas as pd
import numpy as np

import argparse


import xgboost as xgb
import matplotlib as mpl
#from ydata_profiling import ProfileReport

import mlflow
import mlflow.xgboost

import time
from sklearn.metrics import roc_auc_score
# hyperparameter tuning
#from hyperopt import fmin, tpe, hp, SparkTrials, STATUS_OK
#from hyperopt.pyll import scope



from constants import  *

# %%
def plot_one_prediction(df_pred,label="",xl=[-10,10],yl=[-10,10]):
    plt.rc('font', size=8)
    sel=(df_pred.x<xl[1]) & (df_pred.x>xl[0])&(df_pred.y<yl[1]) & (df_pred.y>yl[0])  
    xx=df_pred[sel]["x"]
    yy=df_pred[sel]["y"]
    H, xedges, yedges = np.histogram2d(df_pred[sel]["x"],df_pred[sel]["y"], bins=500)
    H = H.T
    plt.pcolormesh(xedges, yedges, H, cmap=plt.cm.jet, norm=mpl.colors.LogNorm())
    #xl=[df_pred[sel]["x"].min(),df_pred[sel]["x"].max()]
    #yl=[df_pred[sel]["y"].min(),df_pred[sel]["y"].max()]

    plt.xlim(xl[0], xl[1])
    plt.ylim(yl[0], yl[1])
    score=round(r2_score(xx, yy,multioutput='variance_weighted'),2)
    plt.title(label+f"score={score} Np="+str(len(df_pred[sel]["x"])))
    plt.xlabel("y")
    plt.ylabel("$\hat{y}$")
    plt.plot(xl,yl,color="black")
    plt.colorbar()
    fig_file=f"{label}.png"
    plt.savefig(fig_file)
    plt.show()
    plt.close()
    return fig_file

def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return (rmse, mae, r2)


# TODO optimize for DASK
def fetch_data(fpath="../data/combined_trainingset2_with_xp_norm.ONE.parq"):
    #df=pd.read_csv(fpath).set_index("source_id")
    df=pd.read_parquet(fpath)
    return df

def okay_condition(trainingset, label="met50"):
    """
    Return a condition that defines an acceptable subset for training
    FA: nur metallicities mit guten uncertainties
    FA: für alle training data ausser VMP: ein [M/H] cut (wegen der grid boundary)
    FA: es heisst: keine white dwarfs
    """
    if label=="met50":
        return (trainingset["survey"] != b'WDs EDR3') & \
               ((trainingset["survey"] == b'VMPs') | (trainingset["met50"] > -2.)) & \
               (trainingset["met84"] - trainingset["met16"] < 0.5) & \
               (np.isfinite(trainingset["bp_coefficients_1"]))
    else:
        return (np.isfinite(trainingset["bp_coefficients_1"]))
    
def prepare_data(trainingset,label, random_state=0, frac=0.1, fillvalue=-9.99, 
                        cachepath="cache"):
    """
    Get the desired training and test data (given one label)
    """
    # Read the file
    # TODO make cache for each label 
    #trainingset = dd.read_parquet(trainfilepath)
    # Add the label if necessary:
    if label=='logdist50':
        trainingset['logdist50'] = np.log10(trainingset['dist50'])
    elif label=='logteff50':
        trainingset['logteff50'] = np.log10(trainingset['teff50'])
    else:
        pass
    # Determine the "okay" part of the training set
    ok  = okay_condition(trainingset, label)
    # Cut out the desired part of the training set and repartition
    # Currently no DASK
    trainingset = trainingset[ok][features + [label]].sample(frac=frac).fillna(fillvalue)#.persist()#repartition(npartitions=256)
    
    ## Make weights
    trainlabels   = trainingset[label]
    ## First the histogram
    hist, bin_edges = np.histogram(trainlabels, bins=30)
    bin_centres     = 0.5 * (bin_edges[1:] + bin_edges[:-1])

    ## Then convert this to a KDE
    kde                    = gaussian_kde(bin_centres, weights=hist, bw_method=bin_edges[1]-bin_edges[0])
    ## Then compute the weights
    trainingset["weights"] = 1.0/kde.evaluate(trainingset[label]) #trainingset[label].map_partitions(lambda x: 1. / kde.evaluate(x))
    
    #weights = trainingset["weights"]
  

    # Split dataframe into input and output columns
    X   = trainingset.drop(columns=[label])#.to_dask_array(lengths=True)
    #y   = trainingset[label]#.to_dask_array(lengths=True)
    # Splitting into train and test
    #train_X, test_X, train_y, test_y = train_test_split(X, y,
    #                  test_size = 0.2, random_state = 123)
    # Compute weights

   
    for icol in trainingset.columns:
        if trainingset[icol].dtype != np.dtype('float32'):
            print(icol,trainingset[icol].dtype)
            trainingset[icol]=trainingset[icol].astype("float32")
    
    return trainingset#train_X, test_X, train_y, test_y
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\h'
# <>:17: SyntaxWarning: invalid escape sequence '\h'
# /tmp/ipykernel_5777/74377218.py:17: SyntaxWarning: invalid escape sequence '\h'
#   plt.ylabel("$\hat{y}$")

# %%
ii=4
label = pred_vec[ii]
rawdata = fetch_data()
data=prepare_data(rawdata,label,random_state=42,frac=0.01)
print(len(data))
print(f"{round(data.memory_usage(index=True).sum()/1024/1024)}MB")
#del(rawdata)
print(f"{round(rawdata.memory_usage(index=True).sum()/1024/1024)}MB")
len(rawdata), len(rawdata[rawdata["survey"] == b'VMPs'])
# Out:
# j_m float64
# h_m float64
# ks_m float64
# w1mpro float64
# w2mpro float64
# w3mpro float64
# w4mpro float64
# vmag float64
# bmag float64
# g_mag float64
# r_mag float64
# i_mag float64
# g_mean_psf_mag float64
# r_mean_psf_mag float64
# i_mean_psf_mag float64
# z_mean_psf_mag float64
# y_mean_psf_mag float64
# u_psf float64
# v_psf float64
# g_psf float64
# r_psf float64
# i_psf float64
# z_psf float64
# weights float64
# 60066
# 11MB
# 4889MB
# (6117438, 3337)

# %%
del(rawdata)

# %%
# RUN:
# cd  D:\Users\arm2arm\Projects\jupyter\MLUtils\mlflow 
# mlflow ui
# or in dev container  
# make start 
def train_sh23_model(data,params,label="target",mlflow_experiment_id=1):
    
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    weights=train["weights"]
    if label != "met50":
        weights=train["weights"]*0.0+1
        
    X_train = train.drop([label,"weights"], axis=1)
    X_test = test.drop([label,"weights"], axis=1)
    y_train = train[[label]]
    y_test = test[[label]]
    
    # enable auto logging
    mlflow.set_tracking_uri("http://localhost:5000")
    mlflow.xgboost.autolog()
    dtrain = xgb.DMatrix(X_train, label=y_train, weight=weights)
    dtest =  xgb.DMatrix(X_test, label=y_test)
   
   
    #xgbRegressor = xgb.XGBRegressor(
    #    **optimized_params
    #    )
    xgb.set_config(verbosity=1)
    with mlflow.start_run(experiment_id=mlflow_experiment_id):
       
        model = xgb.train(params, dtrain, num_boost_round=1000,verbose_eval=True,early_stopping_rounds=10,evals=[(dtrain, "train")])
        # Start prediction
        y_pred = model.predict(dtest)
        df_pred=pd.DataFrame({"x":y_test[label].values,"y":y_pred})
        dflims=df_pred.describe().T
        print(len(df_pred))
        img_fname=plot_one_prediction(df_pred,label)#,[dflims.loc["x"]["25%"]*0.2,dflims.loc["x"]["75%"]*1.8],[dflims.loc["y"]["25%"]*0.2,dflims.loc["y"]["75%"]*1.8])
        mlflow.log_artifact(img_fname)
        (rmse, mae, r2) = eval_metrics(y_test, y_pred)
            
        y_pred = model.predict(dtrain)
        df_pred=pd.DataFrame({"x":y_train[label].values,"y":y_pred})
        dflims=df_pred.describe().T
        img_fname=plot_one_prediction(df_pred,label+"_train_")#,[dflims.loc["x"]["25%"]*0.2,dflims.loc["x"]["75%"]*1.8],[dflims.loc["y"]["25%"]*0.2,dflims.loc["y"]["75%"]*1.8])
        mlflow.log_artifact(img_fname)
    return model,X_train,X_test,y_train,y_test

# %%
learning_rate=[0.1,0.05,0.005]
max_depth=[6,8,12]
min_child_weight=[4,6,8]
# For Tests
params={
"tree_method": "gpu_hist",
#'tree_method':'hist',
"random_state":42,
"learning_rate":0.05,
"max_depth":8,
"min_child_weight":4,
#"n_estimators":2000,
#"eval_metric":"rmsle",
"objective":"reg:squarederror",
"eval_metric":["mae","rmse"],
#"objective":"reg:pseudohubererror",
#"huber_slope":1.0,
"subsample":0.8,
#"eta":0.5
#'num_boost_round':100
#'verbose_eval': False
}
# For GPU 
params={"tree_method": "gpu_hist",
        'learning_rate': 0.09, 
        'max_depth': 7, 
        'min_child_weight': 79.0, 
        'subsample': 0.8,
        "objective":"reg:squarederror",
        "eval_metric":["mae","rmse"],
       }
# For CPU
params={"tree_method": "hist",
        'learning_rate': 0.09, 
        'max_depth': 7, 
        'min_child_weight': 79.0, 
        'subsample': 0.8,
        "objective":"reg:squarederror",
        "eval_metric":["mae","rmse"],
       }

label = pred_vec[ii]
mlflow_experiment_id=0
print(f"total datasets:{len(data)}")
# Out:
# total datasets:60066

# %%
model,X_train,X_test,y_train,y_test=train_sh23_model(data,params,label, mlflow_experiment_id)
# Out:
# 2026/06/05 15:40:52 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# [0]	train-mae:1.02086	train-rmse:1.18074
# [1]	train-mae:0.94073	train-rmse:1.08896
# [2]	train-mae:0.86509	train-rmse:1.00130
# [3]	train-mae:0.80011	train-rmse:0.92549
# [4]	train-mae:0.73699	train-rmse:0.85390
# [5]	train-mae:0.68052	train-rmse:0.79035
# [6]	train-mae:0.62605	train-rmse:0.72946
# [7]	train-mae:0.57912	train-rmse:0.67554
# [8]	train-mae:0.53643	train-rmse:0.62652
# [9]	train-mae:0.50072	train-rmse:0.58438
# [10]	train-mae:0.47821	train-rmse:0.55988
# [11]	train-mae:0.44159	train-rmse:0.51878
# [12]	train-mae:0.41868	train-rmse:0.49618
# [13]	train-mae:0.39245	train-rmse:0.46602
# [14]	train-mae:0.36537	train-rmse:0.43447
# [15]	train-mae:0.34237	train-rmse:0.40729
# [16]	train-mae:0.32295	train-rmse:0.38472
# [17]	train-mae:0.30149	train-rmse:0.36016
# [18]	train-mae:0.28306	train-rmse:0.33941
# [19]	train-mae:0.26681	train-rmse:0.32166
# [20]	train-mae:0.25056	train-rmse:0.30348
# [21]	train-mae:0.23789	train-rmse:0.28966
# [22]	train-mae:0.22571	train-rmse:0.27662
# [23]	train-mae:0.21559	train-rmse:0.26587
# [24]	train-mae:0.20556	train-rmse:0.25417
# [25]	train-mae:0.19500	train-rmse:0.24367
# [26]	train-mae:0.18560	train-rmse:0.23419
# [27]	train-mae:0.17786	train-rmse:0.22642
# [28]	train-mae:0.17305	train-rmse:0.22012
# [29]	train-mae:0.16518	train-rmse:0.21303
# [30]	train-mae:0.16047	train-rmse:0.20841
# [31]	train-mae:0.15528	train-rmse:0.20313
# [32]	train-mae:0.14995	train-rmse:0.19829
# [33]	train-mae:0.14449	train-rmse:0.19340
# [34]	train-mae:0.14024	train-rmse:0.18948
# [35]	train-mae:0.13548	train-rmse:0.18580
# [36]	train-mae:0.13117	train-rmse:0.18238
# [37]	train-mae:0.12947	train-rmse:0.18023
# [38]	train-mae:0.12511	train-rmse:0.17680
# [39]	train-mae:0.12196	train-rmse:0.17426
# [40]	train-mae:0.11806	train-rmse:0.17162
# [41]	train-mae:0.11640	train-rmse:0.16976
# [42]	train-mae:0.11343	train-rmse:0.16743
# [43]	train-mae:0.11047	train-rmse:0.16542
# [44]	train-mae:0.10926	train-rmse:0.16371
# [45]	train-mae:0.10696	train-rmse:0.16191
# [46]	train-mae:0.10657	train-rmse:0.16113
# [47]	train-mae:0.10451	train-rmse:0.15927
# [48]	train-mae:0.10210	train-rmse:0.15763
# [49]	train-mae:0.09973	train-rmse:0.15575
# [50]	train-mae:0.09792	train-rmse:0.15421
# [51]	train-mae:0.09614	train-rmse:0.15280
# [52]	train-mae:0.09431	train-rmse:0.15133
# [53]	train-mae:0.09263	train-rmse:0.15010
# [54]	train-mae:0.09071	train-rmse:0.14866
# [55]	train-mae:0.08968	train-rmse:0.14785
# [56]	train-mae:0.08865	train-rmse:0.14724
# [57]	train-mae:0.08685	train-rmse:0.14595
# [58]	train-mae:0.08584	train-rmse:0.14498
# [59]	train-mae:0.08458	train-rmse:0.14413
# [60]	train-mae:0.08346	train-rmse:0.14334
# [61]	train-mae:0.08525	train-rmse:0.14320
# [62]	train-mae:0.08752	train-rmse:0.14350
# [63]	train-mae:0.08601	train-rmse:0.14270
# [64]	train-mae:0.08481	train-rmse:0.14182
# [65]	train-mae:0.08368	train-rmse:0.14095
# [66]	train-mae:0.08261	train-rmse:0.14034
# [67]	train-mae:0.08164	train-rmse:0.13982
# [68]	train-mae:0.08091	train-rmse:0.13899
# [69]	train-mae:0.08000	train-rmse:0.13861
# [70]	train-mae:0.07882	train-rmse:0.13774
# [71]	train-mae:0.08012	train-rmse:0.13783
# [72]	train-mae:0.07920	train-rmse:0.13713
# [73]	train-mae:0.07837	train-rmse:0.13658
# [74]	train-mae:0.07981	train-rmse:0.13670
# [75]	train-mae:0.07893	train-rmse:0.13614
# [76]	train-mae:0.07835	train-rmse:0.13555
# [77]	train-mae:0.07759	train-rmse:0.13501
# [78]	train-mae:0.07671	train-rmse:0.13458
# [79]	train-mae:0.07585	train-rmse:0.13408
# [80]	train-mae:0.07527	train-rmse:0.13382
# [81]	train-mae:0.07702	train-rmse:0.13404
# [82]	train-mae:0.07629	train-rmse:0.13361
# [83]	train-mae:0.07546	train-rmse:0.13321
# [84]	train-mae:0.07488	train-rmse:0.13278
# [85]	train-mae:0.07397	train-rmse:0.13228
# [86]	train-mae:0.07328	train-rmse:0.13149
# [87]	train-mae:0.07283	train-rmse:0.13126
# [88]	train-mae:0.07223	train-rmse:0.13079
# [89]	train-mae:0.07167	train-rmse:0.13020
# [90]	train-mae:0.07100	train-rmse:0.12954
# [91]	train-mae:0.07058	train-rmse:0.12925
# [92]	train-mae:0.07182	train-rmse:0.12934
# [93]	train-mae:0.07099	train-rmse:0.12852
# [94]	train-mae:0.07035	train-rmse:0.12789
# [95]	train-mae:0.06960	train-rmse:0.12730
# [96]	train-mae:0.06903	train-rmse:0.12656
# [97]	train-mae:0.06862	train-rmse:0.12630
# [98]	train-mae:0.06826	train-rmse:0.12580
# [99]	train-mae:0.06804	train-rmse:0.12549
# [100]	train-mae:0.06782	train-rmse:0.12529
# [101]	train-mae:0.06740	train-rmse:0.12497
# [102]	train-mae:0.06692	train-rmse:0.12458
# [103]	train-mae:0.06661	train-rmse:0.12434
# [104]	train-mae:0.06624	train-rmse:0.12386
# [105]	train-mae:0.06587	train-rmse:0.12348
# [106]	train-mae:0.06543	train-rmse:0.12312
# [107]	train-mae:0.06552	train-rmse:0.12279
# [108]	train-mae:0.06509	train-rmse:0.12216
# [109]	train-mae:0.06475	train-rmse:0.12159
# [110]	train-mae:0.06447	train-rmse:0.12114
# [111]	train-mae:0.06409	train-rmse:0.12077
# [112]	train-mae:0.06370	train-rmse:0.12031
# [113]	train-mae:0.06325	train-rmse:0.11993
# [114]	train-mae:0.06280	train-rmse:0.11940
# [115]	train-mae:0.06254	train-rmse:0.11899
# [116]	train-mae:0.06213	train-rmse:0.11852
# [117]	train-mae:0.06200	train-rmse:0.11811
# [118]	train-mae:0.06190	train-rmse:0.11781
# [119]	train-mae:0.06178	train-rmse:0.11745
# [120]	train-mae:0.06339	train-rmse:0.11724
# [121]	train-mae:0.06285	train-rmse:0.11691
# [122]	train-mae:0.06249	train-rmse:0.11668
# [123]	train-mae:0.06220	train-rmse:0.11644
# [124]	train-mae:0.06192	train-rmse:0.11605
# [125]	train-mae:0.06174	train-rmse:0.11572
# [126]	train-mae:0.06161	train-rmse:0.11521
# [127]	train-mae:0.06121	train-rmse:0.11499
# [128]	train-mae:0.06107	train-rmse:0.11467
# [129]	train-mae:0.06075	train-rmse:0.11441
# [130]	train-mae:0.06046	train-rmse:0.11416
# [131]	train-mae:0.06048	train-rmse:0.11386
# [132]	train-mae:0.05967	train-rmse:0.11354
# [133]	train-mae:0.05934	train-rmse:0.11322
# [134]	train-mae:0.05915	train-rmse:0.11302
# [135]	train-mae:0.05945	train-rmse:0.11278
# [136]	train-mae:0.05911	train-rmse:0.11253
# [137]	train-mae:0.05876	train-rmse:0.11229
# [138]	train-mae:0.05835	train-rmse:0.11198
# [139]	train-mae:0.05799	train-rmse:0.11166
# [140]	train-mae:0.05786	train-rmse:0.11149
# [141]	train-mae:0.05768	train-rmse:0.11118
# [142]	train-mae:0.05768	train-rmse:0.11104
# [143]	train-mae:0.05733	train-rmse:0.11079
# [144]	train-mae:0.05719	train-rmse:0.11056
# [145]	train-mae:0.05779	train-rmse:0.11023
# [146]	train-mae:0.05760	train-rmse:0.10996
# [147]	train-mae:0.05730	train-rmse:0.10980
# [148]	train-mae:0.05692	train-rmse:0.10946
# [149]	train-mae:0.05680	train-rmse:0.10925
# [150]	train-mae:0.05645	train-rmse:0.10903
# [151]	train-mae:0.05659	train-rmse:0.10870
# [152]	train-mae:0.05661	train-rmse:0.10852
# [153]	train-mae:0.05618	train-rmse:0.10812
# [154]	train-mae:0.05700	train-rmse:0.10789
# [155]	train-mae:0.05662	train-rmse:0.10762
# [156]	train-mae:0.05624	train-rmse:0.10723
# [157]	train-mae:0.05594	train-rmse:0.10695
# [158]	train-mae:0.05555	train-rmse:0.10661
# [159]	train-mae:0.05611	train-rmse:0.10653
# [160]	train-mae:0.05576	train-rmse:0.10635
# [161]	train-mae:0.05536	train-rmse:0.10611
# [162]	train-mae:0.05498	train-rmse:0.10581
# [163]	train-mae:0.05472	train-rmse:0.10565
# [164]	train-mae:0.05569	train-rmse:0.10560
# [165]	train-mae:0.05520	train-rmse:0.10527
# [166]	train-mae:0.05486	train-rmse:0.10502
# [167]	train-mae:0.05458	train-rmse:0.10485
# [168]	train-mae:0.05426	train-rmse:0.10462
# [169]	train-mae:0.05397	train-rmse:0.10444
# [170]	train-mae:0.05379	train-rmse:0.10417
# [171]	train-mae:0.05367	train-rmse:0.10401
# [172]	train-mae:0.05378	train-rmse:0.10369
# [173]	train-mae:0.05356	train-rmse:0.10336
# [174]	train-mae:0.05324	train-rmse:0.10324
# [175]	train-mae:0.05301	train-rmse:0.10313
# [176]	train-mae:0.05274	train-rmse:0.10294
# [177]	train-mae:0.05306	train-rmse:0.10283
# [178]	train-mae:0.05275	train-rmse:0.10260
# [179]	train-mae:0.05288	train-rmse:0.10247
# [180]	train-mae:0.05269	train-rmse:0.10221
# [181]	train-mae:0.05237	train-rmse:0.10188
# [182]	train-mae:0.05212	train-rmse:0.10151
# [183]	train-mae:0.05172	train-rmse:0.10122
# [184]	train-mae:0.05141	train-rmse:0.10098
# [185]	train-mae:0.05115	train-rmse:0.10070
# [186]	train-mae:0.05094	train-rmse:0.10051
# [187]	train-mae:0.05089	train-rmse:0.10031
# [188]	train-mae:0.05065	train-rmse:0.10012
# [189]	train-mae:0.05040	train-rmse:0.09996
# [190]	train-mae:0.05022	train-rmse:0.09976
# [191]	train-mae:0.05009	train-rmse:0.09959
# [192]	train-mae:0.04997	train-rmse:0.09942
# [193]	train-mae:0.04976	train-rmse:0.09920
# [194]	train-mae:0.04952	train-rmse:0.09891
# [195]	train-mae:0.04933	train-rmse:0.09876
# [196]	train-mae:0.04923	train-rmse:0.09865
# [197]	train-mae:0.04913	train-rmse:0.09854
# [198]	train-mae:0.04897	train-rmse:0.09835
# [199]	train-mae:0.04886	train-rmse:0.09814
# [200]	train-mae:0.04859	train-rmse:0.09785
# [201]	train-mae:0.04842	train-rmse:0.09769
# [202]	train-mae:0.04835	train-rmse:0.09748
# [203]	train-mae:0.04826	train-rmse:0.09735
# [204]	train-mae:0.04835	train-rmse:0.09723
# [205]	train-mae:0.04888	train-rmse:0.09713
# [206]	train-mae:0.04874	train-rmse:0.09688
# [207]	train-mae:0.04851	train-rmse:0.09670
# [208]	train-mae:0.04851	train-rmse:0.09651
# [209]	train-mae:0.04830	train-rmse:0.09640
# [210]	train-mae:0.04807	train-rmse:0.09629
# [211]	train-mae:0.04782	train-rmse:0.09609
# [212]	train-mae:0.04799	train-rmse:0.09590
# [213]	train-mae:0.04779	train-rmse:0.09572
# [214]	train-mae:0.04750	train-rmse:0.09557
# [215]	train-mae:0.04740	train-rmse:0.09544
# [216]	train-mae:0.04724	train-rmse:0.09527
# [217]	train-mae:0.04708	train-rmse:0.09517
# [218]	train-mae:0.04686	train-rmse:0.09497
# [219]	train-mae:0.04667	train-rmse:0.09478
# [220]	train-mae:0.04645	train-rmse:0.09459
# [221]	train-mae:0.04628	train-rmse:0.09439
# [222]	train-mae:0.04612	train-rmse:0.09415
# [223]	train-mae:0.04596	train-rmse:0.09394
# [224]	train-mae:0.04590	train-rmse:0.09370
# [225]	train-mae:0.04578	train-rmse:0.09363
# [226]	train-mae:0.04644	train-rmse:0.09349
# [227]	train-mae:0.04625	train-rmse:0.09337
# [228]	train-mae:0.04618	train-rmse:0.09328
# [229]	train-mae:0.04606	train-rmse:0.09311
# [230]	train-mae:0.04570	train-rmse:0.09288
# [231]	train-mae:0.04553	train-rmse:0.09273
# [232]	train-mae:0.04535	train-rmse:0.09256
# [233]	train-mae:0.04525	train-rmse:0.09246
# [234]	train-mae:0.04508	train-rmse:0.09236
# [235]	train-mae:0.04495	train-rmse:0.09223
# [236]	train-mae:0.04490	train-rmse:0.09215
# [237]	train-mae:0.04619	train-rmse:0.09213
# [238]	train-mae:0.04598	train-rmse:0.09202
# [239]	train-mae:0.04577	train-rmse:0.09192
# [240]	train-mae:0.04611	train-rmse:0.09190
# [241]	train-mae:0.04585	train-rmse:0.09179
# [242]	train-mae:0.04562	train-rmse:0.09167
# [243]	train-mae:0.04554	train-rmse:0.09151
# [244]	train-mae:0.04552	train-rmse:0.09126
# [245]	train-mae:0.04679	train-rmse:0.09138
# [246]	train-mae:0.04646	train-rmse:0.09121
# [247]	train-mae:0.04625	train-rmse:0.09105
# [248]	train-mae:0.04611	train-rmse:0.09092
# [249]	train-mae:0.04582	train-rmse:0.09078
# [250]	train-mae:0.04554	train-rmse:0.09067
# [251]	train-mae:0.04531	train-rmse:0.09057
# [252]	train-mae:0.04550	train-rmse:0.09044
# [253]	train-mae:0.04512	train-rmse:0.09030
# [254]	train-mae:0.04485	train-rmse:0.09015
# [255]	train-mae:0.04466	train-rmse:0.09003
# [256]	train-mae:0.04450	train-rmse:0.08994
# [257]	train-mae:0.04426	train-rmse:0.08983
# [258]	train-mae:0.04417	train-rmse:0.08974
# [259]	train-mae:0.04400	train-rmse:0.08965
# [260]	train-mae:0.04379	train-rmse:0.08953
# [261]	train-mae:0.04432	train-rmse:0.08953
# [262]	train-mae:0.04412	train-rmse:0.08942
# [263]	train-mae:0.04399	train-rmse:0.08927
# [264]	train-mae:0.04407	train-rmse:0.08906
# [265]	train-mae:0.04387	train-rmse:0.08889
# [266]	train-mae:0.04368	train-rmse:0.08878
# [267]	train-mae:0.04345	train-rmse:0.08860
# [268]	train-mae:0.04323	train-rmse:0.08843
# [269]	train-mae:0.04302	train-rmse:0.08831
# [270]	train-mae:0.04286	train-rmse:0.08824
# [271]	train-mae:0.04272	train-rmse:0.08815
# [272]	train-mae:0.04258	train-rmse:0.08802
# [273]	train-mae:0.04243	train-rmse:0.08796
# [274]	train-mae:0.04225	train-rmse:0.08785
# [275]	train-mae:0.04217	train-rmse:0.08772
# [276]	train-mae:0.04333	train-rmse:0.08770
# [277]	train-mae:0.04310	train-rmse:0.08753
# [278]	train-mae:0.04292	train-rmse:0.08748
# [279]	train-mae:0.04341	train-rmse:0.08745
# [280]	train-mae:0.04315	train-rmse:0.08735
# [281]	train-mae:0.04299	train-rmse:0.08722
# [282]	train-mae:0.04278	train-rmse:0.08711
# [283]	train-mae:0.04257	train-rmse:0.08705
# [284]	train-mae:0.04237	train-rmse:0.08696
# [285]	train-mae:0.04222	train-rmse:0.08690
# [286]	train-mae:0.04210	train-rmse:0.08680
# [287]	train-mae:0.04204	train-rmse:0.08674
# [288]	train-mae:0.04185	train-rmse:0.08666
# [289]	train-mae:0.04171	train-rmse:0.08655
# [290]	train-mae:0.04164	train-rmse:0.08648
# [291]	train-mae:0.04144	train-rmse:0.08633
# [292]	train-mae:0.04133	train-rmse:0.08623
# [293]	train-mae:0.04117	train-rmse:0.08614
# [294]	train-mae:0.04105	train-rmse:0.08608
# [295]	train-mae:0.04093	train-rmse:0.08600
# [296]	train-mae:0.04082	train-rmse:0.08590
# [297]	train-mae:0.04074	train-rmse:0.08584
# [298]	train-mae:0.04058	train-rmse:0.08565
# [299]	train-mae:0.04051	train-rmse:0.08552
# [300]	train-mae:0.04039	train-rmse:0.08540
# [301]	train-mae:0.04029	train-rmse:0.08521
# [302]	train-mae:0.04023	train-rmse:0.08507
# [303]	train-mae:0.04007	train-rmse:0.08486
# [304]	train-mae:0.04005	train-rmse:0.08472
# [305]	train-mae:0.04001	train-rmse:0.08468
# [306]	train-mae:0.03998	train-rmse:0.08464
# [307]	train-mae:0.03989	train-rmse:0.08451
# [308]	train-mae:0.03986	train-rmse:0.08436
# [309]	train-mae:0.03974	train-rmse:0.08431
# [310]	train-mae:0.03964	train-rmse:0.08422
# [311]	train-mae:0.03962	train-rmse:0.08412
# [312]	train-mae:0.03955	train-rmse:0.08400
# [313]	train-mae:0.03993	train-rmse:0.08397
# [314]	train-mae:0.03980	train-rmse:0.08381
# [315]	train-mae:0.03973	train-rmse:0.08373
# [316]	train-mae:0.03957	train-rmse:0.08358
# [317]	train-mae:0.03945	train-rmse:0.08348
# [318]	train-mae:0.03936	train-rmse:0.08342
# [319]	train-mae:0.03928	train-rmse:0.08335
# [320]	train-mae:0.03921	train-rmse:0.08327
# [321]	train-mae:0.03914	train-rmse:0.08316
# [322]	train-mae:0.03901	train-rmse:0.08302
# [323]	train-mae:0.03893	train-rmse:0.08294
# [324]	train-mae:0.03930	train-rmse:0.08289
# [325]	train-mae:0.03917	train-rmse:0.08280
# [326]	train-mae:0.03909	train-rmse:0.08275
# [327]	train-mae:0.03898	train-rmse:0.08263
# [328]	train-mae:0.03898	train-rmse:0.08258
# [329]	train-mae:0.03889	train-rmse:0.08240
# [330]	train-mae:0.03914	train-rmse:0.08234
# [331]	train-mae:0.03901	train-rmse:0.08223
# [332]	train-mae:0.03889	train-rmse:0.08210
# [333]	train-mae:0.03878	train-rmse:0.08199
# [334]	train-mae:0.03868	train-rmse:0.08194
# [335]	train-mae:0.03856	train-rmse:0.08187
# [336]	train-mae:0.03842	train-rmse:0.08174
# [337]	train-mae:0.03832	train-rmse:0.08165
# [338]	train-mae:0.03831	train-rmse:0.08160
# [339]	train-mae:0.03818	train-rmse:0.08150
# [340]	train-mae:0.03803	train-rmse:0.08137
# [341]	train-mae:0.03801	train-rmse:0.08131
# [342]	train-mae:0.03794	train-rmse:0.08123
# [343]	train-mae:0.03823	train-rmse:0.08117
# [344]	train-mae:0.03816	train-rmse:0.08107
# [345]	train-mae:0.03806	train-rmse:0.08101
# [346]	train-mae:0.03797	train-rmse:0.08095
# [347]	train-mae:0.03787	train-rmse:0.08088
# [348]	train-mae:0.03779	train-rmse:0.08073
# [349]	train-mae:0.03784	train-rmse:0.08066
# [350]	train-mae:0.03780	train-rmse:0.08060
# [351]	train-mae:0.03770	train-rmse:0.08052
# [352]	train-mae:0.03764	train-rmse:0.08042
# [353]	train-mae:0.03756	train-rmse:0.08038
# [354]	train-mae:0.03751	train-rmse:0.08030
# [355]	train-mae:0.03740	train-rmse:0.08019
# [356]	train-mae:0.03733	train-rmse:0.08012
# [357]	train-mae:0.03722	train-rmse:0.08003
# [358]	train-mae:0.03716	train-rmse:0.07997
# [359]	train-mae:0.03714	train-rmse:0.07983
# [360]	train-mae:0.03707	train-rmse:0.07976
# [361]	train-mae:0.03699	train-rmse:0.07961
# [362]	train-mae:0.03700	train-rmse:0.07951
# [363]	train-mae:0.03690	train-rmse:0.07937
# [364]	train-mae:0.03697	train-rmse:0.07929
# [365]	train-mae:0.03688	train-rmse:0.07916
# [366]	train-mae:0.03689	train-rmse:0.07909
# [367]	train-mae:0.03682	train-rmse:0.07896
# [368]	train-mae:0.03674	train-rmse:0.07887
# [369]	train-mae:0.03662	train-rmse:0.07876
# [370]	train-mae:0.03657	train-rmse:0.07868
# [371]	train-mae:0.03650	train-rmse:0.07853
# [372]	train-mae:0.03644	train-rmse:0.07846
# [373]	train-mae:0.03736	train-rmse:0.07839
# [374]	train-mae:0.03716	train-rmse:0.07831
# [375]	train-mae:0.03695	train-rmse:0.07821
# [376]	train-mae:0.03687	train-rmse:0.07811
# [377]	train-mae:0.03672	train-rmse:0.07804
# [378]	train-mae:0.03658	train-rmse:0.07798
# [379]	train-mae:0.03607	train-rmse:0.07787
# [380]	train-mae:0.03600	train-rmse:0.07783
# [381]	train-mae:0.03596	train-rmse:0.07776
# [382]	train-mae:0.03584	train-rmse:0.07764
# [383]	train-mae:0.03572	train-rmse:0.07753
# [384]	train-mae:0.03586	train-rmse:0.07744
# [385]	train-mae:0.03578	train-rmse:0.07737
# [386]	train-mae:0.03618	train-rmse:0.07728
# [387]	train-mae:0.03603	train-rmse:0.07720
# [388]	train-mae:0.03590	train-rmse:0.07712
# [389]	train-mae:0.03580	train-rmse:0.07701
# [390]	train-mae:0.03573	train-rmse:0.07693
# [391]	train-mae:0.03559	train-rmse:0.07680
# [392]	train-mae:0.03550	train-rmse:0.07674
# [393]	train-mae:0.03535	train-rmse:0.07666
# [394]	train-mae:0.03562	train-rmse:0.07665
# [395]	train-mae:0.03599	train-rmse:0.07662
# [396]	train-mae:0.03583	train-rmse:0.07653
# [397]	train-mae:0.03579	train-rmse:0.07647
# [398]	train-mae:0.03565	train-rmse:0.07640
# [399]	train-mae:0.03589	train-rmse:0.07638
# [400]	train-mae:0.03580	train-rmse:0.07634
# [401]	train-mae:0.03605	train-rmse:0.07633
# [402]	train-mae:0.03587	train-rmse:0.07623
# [403]	train-mae:0.03570	train-rmse:0.07616
# [404]	train-mae:0.03555	train-rmse:0.07610
# [405]	train-mae:0.03541	train-rmse:0.07604
# [406]	train-mae:0.03529	train-rmse:0.07598
# [407]	train-mae:0.03521	train-rmse:0.07592
# [408]	train-mae:0.03627	train-rmse:0.07602
# [409]	train-mae:0.03609	train-rmse:0.07594
# [410]	train-mae:0.03589	train-rmse:0.07584
# [411]	train-mae:0.03571	train-rmse:0.07574
# [412]	train-mae:0.03554	train-rmse:0.07566
# [413]	train-mae:0.03544	train-rmse:0.07563
# [414]	train-mae:0.03530	train-rmse:0.07559
# [415]	train-mae:0.03515	train-rmse:0.07551
# [416]	train-mae:0.03506	train-rmse:0.07548
# [417]	train-mae:0.03492	train-rmse:0.07539
# [418]	train-mae:0.03485	train-rmse:0.07534
# [419]	train-mae:0.03472	train-rmse:0.07528
# [420]	train-mae:0.03463	train-rmse:0.07522
# [421]	train-mae:0.03451	train-rmse:0.07515
# [422]	train-mae:0.03533	train-rmse:0.07520
# [423]	train-mae:0.03578	train-rmse:0.07517
# [424]	train-mae:0.03575	train-rmse:0.07510
# [425]	train-mae:0.03558	train-rmse:0.07501
# [426]	train-mae:0.03554	train-rmse:0.07493
# [427]	train-mae:0.03533	train-rmse:0.07484
# [428]	train-mae:0.03515	train-rmse:0.07475
# [429]	train-mae:0.03502	train-rmse:0.07471
# [430]	train-mae:0.03501	train-rmse:0.07463
# [431]	train-mae:0.03487	train-rmse:0.07457
# [432]	train-mae:0.03472	train-rmse:0.07451
# [433]	train-mae:0.03459	train-rmse:0.07442
# [434]	train-mae:0.03457	train-rmse:0.07436
# [435]	train-mae:0.03452	train-rmse:0.07428
# [436]	train-mae:0.03439	train-rmse:0.07423
# [437]	train-mae:0.03426	train-rmse:0.07413
# [438]	train-mae:0.03417	train-rmse:0.07408
# [439]	train-mae:0.03405	train-rmse:0.07404
# [440]	train-mae:0.03398	train-rmse:0.07398
# [441]	train-mae:0.03389	train-rmse:0.07393
# [442]	train-mae:0.03376	train-rmse:0.07383
# [443]	train-mae:0.03365	train-rmse:0.07377
# [444]	train-mae:0.03360	train-rmse:0.07373
# [445]	train-mae:0.03350	train-rmse:0.07362
# [446]	train-mae:0.03350	train-rmse:0.07354
# [447]	train-mae:0.03347	train-rmse:0.07348
# [448]	train-mae:0.03342	train-rmse:0.07343
# [449]	train-mae:0.03334	train-rmse:0.07337
# [450]	train-mae:0.03329	train-rmse:0.07331
# [451]	train-mae:0.03322	train-rmse:0.07327
# [452]	train-mae:0.03319	train-rmse:0.07321
# [453]	train-mae:0.03407	train-rmse:0.07320
# [454]	train-mae:0.03394	train-rmse:0.07314
# [455]	train-mae:0.03379	train-rmse:0.07307
# [456]	train-mae:0.03365	train-rmse:0.07301
# [457]	train-mae:0.03358	train-rmse:0.07297
# [458]	train-mae:0.03349	train-rmse:0.07293
# [459]	train-mae:0.03339	train-rmse:0.07289
# [460]	train-mae:0.03384	train-rmse:0.07288
# [461]	train-mae:0.03382	train-rmse:0.07282
# [462]	train-mae:0.03369	train-rmse:0.07275
# [463]	train-mae:0.03353	train-rmse:0.07271
# [464]	train-mae:0.03351	train-rmse:0.07265
# [465]	train-mae:0.03344	train-rmse:0.07255
# [466]	train-mae:0.03331	train-rmse:0.07250
# [467]	train-mae:0.03320	train-rmse:0.07246
# [468]	train-mae:0.03310	train-rmse:0.07240
# [469]	train-mae:0.03297	train-rmse:0.07233
# [470]	train-mae:0.03287	train-rmse:0.07228
# [471]	train-mae:0.03279	train-rmse:0.07222
# [472]	train-mae:0.03261	train-rmse:0.07212
# [473]	train-mae:0.03260	train-rmse:0.07204
# [474]	train-mae:0.03266	train-rmse:0.07201
# [475]	train-mae:0.03257	train-rmse:0.07188
# [476]	train-mae:0.03250	train-rmse:0.07182
# [477]	train-mae:0.03250	train-rmse:0.07175
# [478]	train-mae:0.03241	train-rmse:0.07169
# [479]	train-mae:0.03228	train-rmse:0.07161
# [480]	train-mae:0.03229	train-rmse:0.07154
# [481]	train-mae:0.03220	train-rmse:0.07149
# [482]	train-mae:0.03213	train-rmse:0.07140
# [483]	train-mae:0.03210	train-rmse:0.07132
# [484]	train-mae:0.03201	train-rmse:0.07124
# [485]	train-mae:0.03195	train-rmse:0.07119
# [486]	train-mae:0.03189	train-rmse:0.07112
# [487]	train-mae:0.03190	train-rmse:0.07108
# [488]	train-mae:0.03183	train-rmse:0.07102
# [489]	train-mae:0.03176	train-rmse:0.07094
# [490]	train-mae:0.03172	train-rmse:0.07091
# [491]	train-mae:0.03165	train-rmse:0.07085
# [492]	train-mae:0.03203	train-rmse:0.07083
# [493]	train-mae:0.03194	train-rmse:0.07078
# [494]	train-mae:0.03187	train-rmse:0.07074
# [495]	train-mae:0.03177	train-rmse:0.07065
# [496]	train-mae:0.03168	train-rmse:0.07059
# [497]	train-mae:0.03168	train-rmse:0.07055
# [498]	train-mae:0.03163	train-rmse:0.07053
# [499]	train-mae:0.03160	train-rmse:0.07047
# [500]	train-mae:0.03198	train-rmse:0.07045
# [501]	train-mae:0.03186	train-rmse:0.07038
# [502]	train-mae:0.03176	train-rmse:0.07032
# [503]	train-mae:0.03168	train-rmse:0.07027
# [504]	train-mae:0.03158	train-rmse:0.07021
# [505]	train-mae:0.03171	train-rmse:0.07017
# [506]	train-mae:0.03162	train-rmse:0.07009
# [507]	train-mae:0.03155	train-rmse:0.07006
# [508]	train-mae:0.03148	train-rmse:0.07001
# [509]	train-mae:0.03117	train-rmse:0.06996
# [510]	train-mae:0.03111	train-rmse:0.06989
# [511]	train-mae:0.03106	train-rmse:0.06982
# [512]	train-mae:0.03102	train-rmse:0.06978
# [513]	train-mae:0.03100	train-rmse:0.06973
# [514]	train-mae:0.03095	train-rmse:0.06967
# [515]	train-mae:0.03111	train-rmse:0.06962
# [516]	train-mae:0.03103	train-rmse:0.06957
# [517]	train-mae:0.03105	train-rmse:0.06949
# [518]	train-mae:0.03103	train-rmse:0.06943
# [519]	train-mae:0.03097	train-rmse:0.06939
# [520]	train-mae:0.03095	train-rmse:0.06931
# [521]	train-mae:0.03101	train-rmse:0.06926
# [522]	train-mae:0.03099	train-rmse:0.06920
# [523]	train-mae:0.03102	train-rmse:0.06916
# [524]	train-mae:0.03109	train-rmse:0.06912
# [525]	train-mae:0.03103	train-rmse:0.06904
# [526]	train-mae:0.03102	train-rmse:0.06900
# [527]	train-mae:0.03093	train-rmse:0.06893
# [528]	train-mae:0.03087	train-rmse:0.06888
# [529]	train-mae:0.03078	train-rmse:0.06883
# [530]	train-mae:0.03072	train-rmse:0.06876
# [531]	train-mae:0.03065	train-rmse:0.06873
# [532]	train-mae:0.03069	train-rmse:0.06869
# [533]	train-mae:0.03069	train-rmse:0.06862
# [534]	train-mae:0.03059	train-rmse:0.06852
# [535]	train-mae:0.03052	train-rmse:0.06848
# [536]	train-mae:0.03049	train-rmse:0.06839
# [537]	train-mae:0.03042	train-rmse:0.06835
# [538]	train-mae:0.03034	train-rmse:0.06827
# [539]	train-mae:0.03026	train-rmse:0.06822
# [540]	train-mae:0.03020	train-rmse:0.06814
# [541]	train-mae:0.03017	train-rmse:0.06811
# [542]	train-mae:0.03013	train-rmse:0.06809
# [543]	train-mae:0.03009	train-rmse:0.06803
# [544]	train-mae:0.03002	train-rmse:0.06793
# [545]	train-mae:0.02996	train-rmse:0.06790
# [546]	train-mae:0.02989	train-rmse:0.06780
# [547]	train-mae:0.03022	train-rmse:0.06774
# [548]	train-mae:0.03022	train-rmse:0.06770
# [549]	train-mae:0.03016	train-rmse:0.06766
# [550]	train-mae:0.03011	train-rmse:0.06763
# [551]	train-mae:0.03005	train-rmse:0.06758
# [552]	train-mae:0.02999	train-rmse:0.06752
# [553]	train-mae:0.02992	train-rmse:0.06747
# [554]	train-mae:0.02987	train-rmse:0.06741
# [555]	train-mae:0.03024	train-rmse:0.06741
# [556]	train-mae:0.03013	train-rmse:0.06737
# [557]	train-mae:0.03006	train-rmse:0.06735
# [558]	train-mae:0.02998	train-rmse:0.06733
# [559]	train-mae:0.02991	train-rmse:0.06730
# [560]	train-mae:0.02993	train-rmse:0.06724
# [561]	train-mae:0.02990	train-rmse:0.06718
# [562]	train-mae:0.02981	train-rmse:0.06714
# [563]	train-mae:0.02975	train-rmse:0.06709
# [564]	train-mae:0.02971	train-rmse:0.06706
# [565]	train-mae:0.02964	train-rmse:0.06703
# [566]	train-mae:0.02961	train-rmse:0.06698
# [567]	train-mae:0.02961	train-rmse:0.06696
# [568]	train-mae:0.02957	train-rmse:0.06689
# [569]	train-mae:0.02953	train-rmse:0.06686
# [570]	train-mae:0.02948	train-rmse:0.06680
# [571]	train-mae:0.02985	train-rmse:0.06677
# [572]	train-mae:0.02972	train-rmse:0.06670
# [573]	train-mae:0.02963	train-rmse:0.06667
# [574]	train-mae:0.02957	train-rmse:0.06664
# [575]	train-mae:0.02951	train-rmse:0.06661
# [576]	train-mae:0.02949	train-rmse:0.06658
# [577]	train-mae:0.02941	train-rmse:0.06654
# [578]	train-mae:0.02935	train-rmse:0.06651
# [579]	train-mae:0.02928	train-rmse:0.06648
# [580]	train-mae:0.02922	train-rmse:0.06642
# [581]	train-mae:0.02916	train-rmse:0.06637
# [582]	train-mae:0.02915	train-rmse:0.06634
# [583]	train-mae:0.02912	train-rmse:0.06631
# [584]	train-mae:0.02905	train-rmse:0.06623
# [585]	train-mae:0.02902	train-rmse:0.06618
# [586]	train-mae:0.02896	train-rmse:0.06609
# [587]	train-mae:0.02894	train-rmse:0.06601
# [588]	train-mae:0.02891	train-rmse:0.06597
# [589]	train-mae:0.02886	train-rmse:0.06593
# [590]	train-mae:0.02881	train-rmse:0.06585
# [591]	train-mae:0.02878	train-rmse:0.06580
# [592]	train-mae:0.02872	train-rmse:0.06574
# [593]	train-mae:0.02873	train-rmse:0.06570
# [594]	train-mae:0.02872	train-rmse:0.06562
# [595]	train-mae:0.02870	train-rmse:0.06559
# [596]	train-mae:0.02878	train-rmse:0.06554
# [597]	train-mae:0.02875	train-rmse:0.06550
# [598]	train-mae:0.02872	train-rmse:0.06546
# [599]	train-mae:0.02867	train-rmse:0.06541
# [600]	train-mae:0.02867	train-rmse:0.06537
# [601]	train-mae:0.02865	train-rmse:0.06530
# [602]	train-mae:0.02857	train-rmse:0.06523
# [603]	train-mae:0.02853	train-rmse:0.06518
# [604]	train-mae:0.02852	train-rmse:0.06512
# [605]	train-mae:0.02847	train-rmse:0.06509
# [606]	train-mae:0.02842	train-rmse:0.06506
# [607]	train-mae:0.02839	train-rmse:0.06500
# [608]	train-mae:0.02835	train-rmse:0.06495
# [609]	train-mae:0.02831	train-rmse:0.06491
# [610]	train-mae:0.02837	train-rmse:0.06483
# [611]	train-mae:0.02841	train-rmse:0.06480
# [612]	train-mae:0.02847	train-rmse:0.06474
# [613]	train-mae:0.02843	train-rmse:0.06469
# [614]	train-mae:0.02838	train-rmse:0.06466
# [615]	train-mae:0.02829	train-rmse:0.06462
# [616]	train-mae:0.02832	train-rmse:0.06454
# [617]	train-mae:0.02829	train-rmse:0.06451
# [618]	train-mae:0.02825	train-rmse:0.06449
# [619]	train-mae:0.02816	train-rmse:0.06443
# [620]	train-mae:0.02812	train-rmse:0.06441
# [621]	train-mae:0.02808	train-rmse:0.06437
# [622]	train-mae:0.02820	train-rmse:0.06429
# [623]	train-mae:0.02814	train-rmse:0.06426
# [624]	train-mae:0.02809	train-rmse:0.06423
# [625]	train-mae:0.02804	train-rmse:0.06418
# [626]	train-mae:0.02800	train-rmse:0.06413
# [627]	train-mae:0.02793	train-rmse:0.06408
# [628]	train-mae:0.02789	train-rmse:0.06405
# [629]	train-mae:0.02783	train-rmse:0.06399
# [630]	train-mae:0.02778	train-rmse:0.06395
# [631]	train-mae:0.02774	train-rmse:0.06391
# [632]	train-mae:0.02775	train-rmse:0.06388
# [633]	train-mae:0.02773	train-rmse:0.06386
# [634]	train-mae:0.02775	train-rmse:0.06380
# [635]	train-mae:0.02772	train-rmse:0.06375
# [636]	train-mae:0.02776	train-rmse:0.06369
# [637]	train-mae:0.02773	train-rmse:0.06366
# [638]	train-mae:0.02769	train-rmse:0.06363
# [639]	train-mae:0.02763	train-rmse:0.06358
# [640]	train-mae:0.02762	train-rmse:0.06352
# [641]	train-mae:0.02757	train-rmse:0.06348
# [642]	train-mae:0.02750	train-rmse:0.06340
# [643]	train-mae:0.02744	train-rmse:0.06334
# [644]	train-mae:0.02762	train-rmse:0.06327
# [645]	train-mae:0.02780	train-rmse:0.06324
# [646]	train-mae:0.02772	train-rmse:0.06320
# [647]	train-mae:0.02763	train-rmse:0.06316
# [648]	train-mae:0.02753	train-rmse:0.06311
# [649]	train-mae:0.02747	train-rmse:0.06307
# [650]	train-mae:0.02741	train-rmse:0.06304
# [651]	train-mae:0.02742	train-rmse:0.06301
# [652]	train-mae:0.02742	train-rmse:0.06297
# [653]	train-mae:0.02740	train-rmse:0.06291
# [654]	train-mae:0.02735	train-rmse:0.06287
# [655]	train-mae:0.02783	train-rmse:0.06286
# [656]	train-mae:0.02775	train-rmse:0.06281
# [657]	train-mae:0.02767	train-rmse:0.06275
# [658]	train-mae:0.02758	train-rmse:0.06271
# [659]	train-mae:0.02748	train-rmse:0.06265
# [660]	train-mae:0.02742	train-rmse:0.06261
# [661]	train-mae:0.02735	train-rmse:0.06256
# [662]	train-mae:0.02732	train-rmse:0.06249
# [663]	train-mae:0.02730	train-rmse:0.06244
# [664]	train-mae:0.02722	train-rmse:0.06238
# [665]	train-mae:0.02722	train-rmse:0.06234
# [666]	train-mae:0.02721	train-rmse:0.06229
# [667]	train-mae:0.02720	train-rmse:0.06221
# [668]	train-mae:0.02712	train-rmse:0.06215
# [669]	train-mae:0.02702	train-rmse:0.06209
# [670]	train-mae:0.02695	train-rmse:0.06202
# [671]	train-mae:0.02688	train-rmse:0.06197
# [672]	train-mae:0.02680	train-rmse:0.06190
# [673]	train-mae:0.02675	train-rmse:0.06186
# [674]	train-mae:0.02667	train-rmse:0.06179
# [675]	train-mae:0.02662	train-rmse:0.06174
# [676]	train-mae:0.02658	train-rmse:0.06169
# [677]	train-mae:0.02653	train-rmse:0.06162
# [678]	train-mae:0.02648	train-rmse:0.06159
# [679]	train-mae:0.02644	train-rmse:0.06155
# [680]	train-mae:0.02641	train-rmse:0.06152
# [681]	train-mae:0.02637	train-rmse:0.06147
# [682]	train-mae:0.02632	train-rmse:0.06141
# [683]	train-mae:0.02665	train-rmse:0.06136
# [684]	train-mae:0.02658	train-rmse:0.06134
# [685]	train-mae:0.02660	train-rmse:0.06131
# [686]	train-mae:0.02651	train-rmse:0.06125
# [687]	train-mae:0.02645	train-rmse:0.06123
# [688]	train-mae:0.02641	train-rmse:0.06121
# [689]	train-mae:0.02636	train-rmse:0.06117
# [690]	train-mae:0.02633	train-rmse:0.06112
# [691]	train-mae:0.02629	train-rmse:0.06110
# [692]	train-mae:0.02625	train-rmse:0.06105
# [693]	train-mae:0.02620	train-rmse:0.06102
# [694]	train-mae:0.02614	train-rmse:0.06096
# [695]	train-mae:0.02614	train-rmse:0.06094
# [696]	train-mae:0.02602	train-rmse:0.06090
# [697]	train-mae:0.02601	train-rmse:0.06086
# [698]	train-mae:0.02598	train-rmse:0.06078
# [699]	train-mae:0.02594	train-rmse:0.06073
# [700]	train-mae:0.02601	train-rmse:0.06071
# [701]	train-mae:0.02599	train-rmse:0.06068
# [702]	train-mae:0.02596	train-rmse:0.06064
# [703]	train-mae:0.02614	train-rmse:0.06061
# [704]	train-mae:0.02609	train-rmse:0.06059
# [705]	train-mae:0.02604	train-rmse:0.06055
# [706]	train-mae:0.02598	train-rmse:0.06052
# [707]	train-mae:0.02593	train-rmse:0.06047
# [708]	train-mae:0.02590	train-rmse:0.06041
# [709]	train-mae:0.02587	train-rmse:0.06036
# [710]	train-mae:0.02583	train-rmse:0.06033
# [711]	train-mae:0.02579	train-rmse:0.06030
# [712]	train-mae:0.02573	train-rmse:0.06028
# [713]	train-mae:0.02571	train-rmse:0.06024
# [714]	train-mae:0.02564	train-rmse:0.06021
# [715]	train-mae:0.02571	train-rmse:0.06014
# [716]	train-mae:0.02568	train-rmse:0.06010
# [717]	train-mae:0.02565	train-rmse:0.06005
# [718]	train-mae:0.02560	train-rmse:0.06000
# [719]	train-mae:0.02553	train-rmse:0.05997
# [720]	train-mae:0.02546	train-rmse:0.05992
# [721]	train-mae:0.02546	train-rmse:0.05987
# [722]	train-mae:0.02543	train-rmse:0.05983
# [723]	train-mae:0.02540	train-rmse:0.05982
# [724]	train-mae:0.02533	train-rmse:0.05974
# [725]	train-mae:0.02536	train-rmse:0.05972
# [726]	train-mae:0.02532	train-rmse:0.05968
# [727]	train-mae:0.02529	train-rmse:0.05963
# [728]	train-mae:0.02526	train-rmse:0.05961
# [729]	train-mae:0.02557	train-rmse:0.05957
# [730]	train-mae:0.02550	train-rmse:0.05954
# [731]	train-mae:0.02546	train-rmse:0.05951
# [732]	train-mae:0.02538	train-rmse:0.05950
# [733]	train-mae:0.02537	train-rmse:0.05948
# [734]	train-mae:0.02545	train-rmse:0.05945
# [735]	train-mae:0.02541	train-rmse:0.05941
# [736]	train-mae:0.02534	train-rmse:0.05936
# [737]	train-mae:0.02531	train-rmse:0.05932
# [738]	train-mae:0.02529	train-rmse:0.05928
# [739]	train-mae:0.02523	train-rmse:0.05924
# [740]	train-mae:0.02521	train-rmse:0.05921
# [741]	train-mae:0.02517	train-rmse:0.05919
# [742]	train-mae:0.02515	train-rmse:0.05915
# [743]	train-mae:0.02511	train-rmse:0.05913
# [744]	train-mae:0.02509	train-rmse:0.05910
# [745]	train-mae:0.02506	train-rmse:0.05908
# [746]	train-mae:0.02503	train-rmse:0.05904
# [747]	train-mae:0.02504	train-rmse:0.05901
# [748]	train-mae:0.02501	train-rmse:0.05898
# [749]	train-mae:0.02497	train-rmse:0.05893
# [750]	train-mae:0.02494	train-rmse:0.05890
# [751]	train-mae:0.02491	train-rmse:0.05885
# [752]	train-mae:0.02489	train-rmse:0.05883
# [753]	train-mae:0.02485	train-rmse:0.05879
# [754]	train-mae:0.02484	train-rmse:0.05877
# [755]	train-mae:0.02483	train-rmse:0.05870
# [756]	train-mae:0.02481	train-rmse:0.05867
# [757]	train-mae:0.02481	train-rmse:0.05864
# [758]	train-mae:0.02476	train-rmse:0.05860
# [759]	train-mae:0.02473	train-rmse:0.05857
# [760]	train-mae:0.02488	train-rmse:0.05855
# [761]	train-mae:0.02485	train-rmse:0.05850
# [762]	train-mae:0.02479	train-rmse:0.05844
# [763]	train-mae:0.02474	train-rmse:0.05839
# [764]	train-mae:0.02479	train-rmse:0.05834
# [765]	train-mae:0.02475	train-rmse:0.05833
# [766]	train-mae:0.02471	train-rmse:0.05830
# [767]	train-mae:0.02474	train-rmse:0.05825
# [768]	train-mae:0.02474	train-rmse:0.05822
# [769]	train-mae:0.02468	train-rmse:0.05817
# [770]	train-mae:0.02470	train-rmse:0.05811
# [771]	train-mae:0.02471	train-rmse:0.05808
# [772]	train-mae:0.02467	train-rmse:0.05804
# [773]	train-mae:0.02468	train-rmse:0.05800
# [774]	train-mae:0.02465	train-rmse:0.05794
# [775]	train-mae:0.02458	train-rmse:0.05790
# [776]	train-mae:0.02453	train-rmse:0.05785
# [777]	train-mae:0.02451	train-rmse:0.05782
# [778]	train-mae:0.02446	train-rmse:0.05777
# [779]	train-mae:0.02443	train-rmse:0.05773
# [780]	train-mae:0.02439	train-rmse:0.05767
# [781]	train-mae:0.02436	train-rmse:0.05763
# [782]	train-mae:0.02432	train-rmse:0.05759
# [783]	train-mae:0.02434	train-rmse:0.05754
# [784]	train-mae:0.02431	train-rmse:0.05752
# [785]	train-mae:0.02434	train-rmse:0.05746
# [786]	train-mae:0.02432	train-rmse:0.05742
# [787]	train-mae:0.02435	train-rmse:0.05737
# [788]	train-mae:0.02427	train-rmse:0.05732
# [789]	train-mae:0.02424	train-rmse:0.05726
# [790]	train-mae:0.02419	train-rmse:0.05723
# [791]	train-mae:0.02426	train-rmse:0.05719
# [792]	train-mae:0.02416	train-rmse:0.05715
# [793]	train-mae:0.02435	train-rmse:0.05711
# [794]	train-mae:0.02434	train-rmse:0.05709
# [795]	train-mae:0.02428	train-rmse:0.05706
# [796]	train-mae:0.02423	train-rmse:0.05704
# [797]	train-mae:0.02417	train-rmse:0.05701
# [798]	train-mae:0.02426	train-rmse:0.05699
# [799]	train-mae:0.02419	train-rmse:0.05695
# [800]	train-mae:0.02415	train-rmse:0.05691
# [801]	train-mae:0.02416	train-rmse:0.05687
# [802]	train-mae:0.02412	train-rmse:0.05685
# [803]	train-mae:0.02407	train-rmse:0.05681
# [804]	train-mae:0.02404	train-rmse:0.05678
# [805]	train-mae:0.02407	train-rmse:0.05674
# [806]	train-mae:0.02404	train-rmse:0.05668
# [807]	train-mae:0.02398	train-rmse:0.05665
# [808]	train-mae:0.02393	train-rmse:0.05660
# [809]	train-mae:0.02393	train-rmse:0.05657
# [810]	train-mae:0.02388	train-rmse:0.05653
# [811]	train-mae:0.02383	train-rmse:0.05648
# [812]	train-mae:0.02382	train-rmse:0.05645
# [813]	train-mae:0.02380	train-rmse:0.05642
# [814]	train-mae:0.02378	train-rmse:0.05638
# [815]	train-mae:0.02373	train-rmse:0.05635
# [816]	train-mae:0.02368	train-rmse:0.05629
# [817]	train-mae:0.02365	train-rmse:0.05626
# [818]	train-mae:0.02363	train-rmse:0.05624
# [819]	train-mae:0.02360	train-rmse:0.05621
# [820]	train-mae:0.02375	train-rmse:0.05618
# [821]	train-mae:0.02388	train-rmse:0.05616
# [822]	train-mae:0.02381	train-rmse:0.05613
# [823]	train-mae:0.02375	train-rmse:0.05609
# [824]	train-mae:0.02372	train-rmse:0.05607
# [825]	train-mae:0.02364	train-rmse:0.05603
# [826]	train-mae:0.02361	train-rmse:0.05601
# [827]	train-mae:0.02358	train-rmse:0.05599
# [828]	train-mae:0.02365	train-rmse:0.05597
# [829]	train-mae:0.02381	train-rmse:0.05594
# [830]	train-mae:0.02375	train-rmse:0.05591
# [831]	train-mae:0.02370	train-rmse:0.05589
# [832]	train-mae:0.02365	train-rmse:0.05586
# [833]	train-mae:0.02361	train-rmse:0.05584
# [834]	train-mae:0.02355	train-rmse:0.05581
# [835]	train-mae:0.02352	train-rmse:0.05576
# [836]	train-mae:0.02346	train-rmse:0.05572
# [837]	train-mae:0.02360	train-rmse:0.05571
# [838]	train-mae:0.02363	train-rmse:0.05569
# [839]	train-mae:0.02357	train-rmse:0.05566
# [840]	train-mae:0.02351	train-rmse:0.05562
# [841]	train-mae:0.02348	train-rmse:0.05559
# [842]	train-mae:0.02343	train-rmse:0.05558
# [843]	train-mae:0.02340	train-rmse:0.05555
# [844]	train-mae:0.02337	train-rmse:0.05552
# [845]	train-mae:0.02333	train-rmse:0.05550
# [846]	train-mae:0.02331	train-rmse:0.05547
# [847]	train-mae:0.02328	train-rmse:0.05544
# [848]	train-mae:0.02325	train-rmse:0.05542
# [849]	train-mae:0.02320	train-rmse:0.05535
# [850]	train-mae:0.02321	train-rmse:0.05533
# [851]	train-mae:0.02319	train-rmse:0.05529
# [852]	train-mae:0.02316	train-rmse:0.05526
# [853]	train-mae:0.02311	train-rmse:0.05524
# [854]	train-mae:0.02309	train-rmse:0.05523
# [855]	train-mae:0.02319	train-rmse:0.05519
# [856]	train-mae:0.02318	train-rmse:0.05515
# [857]	train-mae:0.02316	train-rmse:0.05511
# [858]	train-mae:0.02312	train-rmse:0.05510
# [859]	train-mae:0.02307	train-rmse:0.05507
# [860]	train-mae:0.02302	train-rmse:0.05506
# [861]	train-mae:0.02300	train-rmse:0.05503
# [862]	train-mae:0.02296	train-rmse:0.05500
# [863]	train-mae:0.02294	train-rmse:0.05496
# [864]	train-mae:0.02291	train-rmse:0.05495
# [865]	train-mae:0.02289	train-rmse:0.05493
# [866]	train-mae:0.02286	train-rmse:0.05488
# [867]	train-mae:0.02282	train-rmse:0.05484
# [868]	train-mae:0.02281	train-rmse:0.05482
# [869]	train-mae:0.02277	train-rmse:0.05477
# [870]	train-mae:0.02275	train-rmse:0.05475
# [871]	train-mae:0.02296	train-rmse:0.05470
# [872]	train-mae:0.02294	train-rmse:0.05469
# [873]	train-mae:0.02289	train-rmse:0.05467
# [874]	train-mae:0.02284	train-rmse:0.05464
# [875]	train-mae:0.02280	train-rmse:0.05463
# [876]	train-mae:0.02277	train-rmse:0.05458
# [877]	train-mae:0.02274	train-rmse:0.05454
# [878]	train-mae:0.02274	train-rmse:0.05453
# [879]	train-mae:0.02271	train-rmse:0.05450
# [880]	train-mae:0.02270	train-rmse:0.05446
# [881]	train-mae:0.02271	train-rmse:0.05442
# [882]	train-mae:0.02269	train-rmse:0.05440
# [883]	train-mae:0.02266	train-rmse:0.05438
# [884]	train-mae:0.02267	train-rmse:0.05435
# [885]	train-mae:0.02265	train-rmse:0.05432
# [886]	train-mae:0.02262	train-rmse:0.05427
# [887]	train-mae:0.02255	train-rmse:0.05423
# [888]	train-mae:0.02253	train-rmse:0.05420
# [889]	train-mae:0.02251	train-rmse:0.05417
# [890]	train-mae:0.02248	train-rmse:0.05413
# [891]	train-mae:0.02246	train-rmse:0.05411
# [892]	train-mae:0.02246	train-rmse:0.05409
# [893]	train-mae:0.02240	train-rmse:0.05403
# [894]	train-mae:0.02240	train-rmse:0.05401
# [895]	train-mae:0.02238	train-rmse:0.05398
# [896]	train-mae:0.02236	train-rmse:0.05395
# [897]	train-mae:0.02233	train-rmse:0.05391
# [898]	train-mae:0.02232	train-rmse:0.05389
# [899]	train-mae:0.02230	train-rmse:0.05385
# [900]	train-mae:0.02229	train-rmse:0.05384
# [901]	train-mae:0.02265	train-rmse:0.05383
# [902]	train-mae:0.02259	train-rmse:0.05379
# [903]	train-mae:0.02259	train-rmse:0.05375
# [904]	train-mae:0.02259	train-rmse:0.05372
# [905]	train-mae:0.02254	train-rmse:0.05369
# [906]	train-mae:0.02248	train-rmse:0.05365
# [907]	train-mae:0.02246	train-rmse:0.05363
# [908]	train-mae:0.02242	train-rmse:0.05361
# [909]	train-mae:0.02238	train-rmse:0.05359
# [910]	train-mae:0.02245	train-rmse:0.05356
# [911]	train-mae:0.02248	train-rmse:0.05353
# [912]	train-mae:0.02273	train-rmse:0.05349
# [913]	train-mae:0.02265	train-rmse:0.05346
# [914]	train-mae:0.02259	train-rmse:0.05343
# [915]	train-mae:0.02255	train-rmse:0.05341
# [916]	train-mae:0.02249	train-rmse:0.05339
# [917]	train-mae:0.02240	train-rmse:0.05335
# [918]	train-mae:0.02235	train-rmse:0.05333
# [919]	train-mae:0.02229	train-rmse:0.05329
# [920]	train-mae:0.02226	train-rmse:0.05327
# [921]	train-mae:0.02222	train-rmse:0.05325
# [922]	train-mae:0.02243	train-rmse:0.05325
# [923]	train-mae:0.02265	train-rmse:0.05326
# [924]	train-mae:0.02259	train-rmse:0.05324
# [925]	train-mae:0.02253	train-rmse:0.05320
# [926]	train-mae:0.02245	train-rmse:0.05318
# [927]	train-mae:0.02238	train-rmse:0.05316
# [928]	train-mae:0.02234	train-rmse:0.05315
# [929]	train-mae:0.02228	train-rmse:0.05312
# [930]	train-mae:0.02226	train-rmse:0.05309
# [931]	train-mae:0.02220	train-rmse:0.05306
# [932]	train-mae:0.02216	train-rmse:0.05305
# [933]	train-mae:0.02210	train-rmse:0.05303
# [934]	train-mae:0.02206	train-rmse:0.05301
# [935]	train-mae:0.02205	train-rmse:0.05299
# [936]	train-mae:0.02202	train-rmse:0.05297
# [937]	train-mae:0.02200	train-rmse:0.05295
# [938]	train-mae:0.02196	train-rmse:0.05294
# [939]	train-mae:0.02195	train-rmse:0.05293
# [940]	train-mae:0.02192	train-rmse:0.05292
# [941]	train-mae:0.02189	train-rmse:0.05289
# [942]	train-mae:0.02186	train-rmse:0.05287
# [943]	train-mae:0.02183	train-rmse:0.05283
# [944]	train-mae:0.02181	train-rmse:0.05281
# [945]	train-mae:0.02180	train-rmse:0.05279
# [946]	train-mae:0.02178	train-rmse:0.05277
# [947]	train-mae:0.02176	train-rmse:0.05274
# [948]	train-mae:0.02194	train-rmse:0.05274
# [949]	train-mae:0.02225	train-rmse:0.05274
# [950]	train-mae:0.02218	train-rmse:0.05273
# [951]	train-mae:0.02212	train-rmse:0.05272
# [952]	train-mae:0.02209	train-rmse:0.05270
# [953]	train-mae:0.02205	train-rmse:0.05269
# [954]	train-mae:0.02200	train-rmse:0.05268
# [955]	train-mae:0.02199	train-rmse:0.05266
# [956]	train-mae:0.02194	train-rmse:0.05264
# [957]	train-mae:0.02210	train-rmse:0.05263
# [958]	train-mae:0.02204	train-rmse:0.05261
# [959]	train-mae:0.02224	train-rmse:0.05261
# [960]	train-mae:0.02218	train-rmse:0.05259
# [961]	train-mae:0.02216	train-rmse:0.05256
# [962]	train-mae:0.02208	train-rmse:0.05252
# [963]	train-mae:0.02203	train-rmse:0.05250
# [964]	train-mae:0.02198	train-rmse:0.05248
# [965]	train-mae:0.02196	train-rmse:0.05244
# [966]	train-mae:0.02190	train-rmse:0.05243
# [967]	train-mae:0.02185	train-rmse:0.05241
# [968]	train-mae:0.02180	train-rmse:0.05239
# [969]	train-mae:0.02176	train-rmse:0.05238
# [970]	train-mae:0.02172	train-rmse:0.05236
# [971]	train-mae:0.02169	train-rmse:0.05233
# [972]	train-mae:0.02166	train-rmse:0.05230
# [973]	train-mae:0.02163	train-rmse:0.05229
# [974]	train-mae:0.02160	train-rmse:0.05226
# [975]	train-mae:0.02159	train-rmse:0.05224
# [976]	train-mae:0.02158	train-rmse:0.05224
# [977]	train-mae:0.02156	train-rmse:0.05220
# [978]	train-mae:0.02153	train-rmse:0.05218
# [979]	train-mae:0.02151	train-rmse:0.05215
# [980]	train-mae:0.02149	train-rmse:0.05213
# [981]	train-mae:0.02148	train-rmse:0.05211
# [982]	train-mae:0.02146	train-rmse:0.05210
# [983]	train-mae:0.02149	train-rmse:0.05208
# [984]	train-mae:0.02182	train-rmse:0.05206
# [985]	train-mae:0.02175	train-rmse:0.05203
# [986]	train-mae:0.02188	train-rmse:0.05203
# [987]	train-mae:0.02184	train-rmse:0.05200
# [988]	train-mae:0.02154	train-rmse:0.05194
# [989]	train-mae:0.02151	train-rmse:0.05192
# [990]	train-mae:0.02148	train-rmse:0.05189
# [991]	train-mae:0.02144	train-rmse:0.05187
# [992]	train-mae:0.02147	train-rmse:0.05184
# [993]	train-mae:0.02147	train-rmse:0.05180
# [994]	train-mae:0.02144	train-rmse:0.05178
# [995]	train-mae:0.02142	train-rmse:0.05175
# [996]	train-mae:0.02139	train-rmse:0.05172
# [997]	train-mae:0.02136	train-rmse:0.05171
# [998]	train-mae:0.02134	train-rmse:0.05170
# [999]	train-mae:0.02133	train-rmse:0.05168
# 2026/06/05 15:41:47 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/usr/local/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [15:41:47] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 15017

# %% [raw]
# params={
# "max_depth":17,
# "n_estimators":2110,
# "colsample_bytree":0.5,
# "min_child_weight":330,
# "subsample":0.8,
# "eta":0.02,
# "objective":'reg:squarederror',
# "tree_method":'gpu_hist'
# }
# train_sh23_model(data,params,label, mlflow_experiment_id)

# %% [raw]
# params={'tree_method': 'gpu_hist', 'subsample': 0.5,
#         'objective': 'reg:pseudohubererror', 'nthread': 4,
#         #'n_estimators': 1500,
#         'max_depth': 16,
#         'learning_rate': 0.1, 'eval_metric': 'mae',
#         #"sample_type" :"gradient_based"
#        }
# label = pred_vec[ii]
# model,X_train,X_test,y_train,y_test=train_sh23_model(data,params,label, mlflow_experiment_id)

# %% [raw]
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error
#
# train, test = train_test_split(data)
# # The predicted column is "quality" which is a scalar from [3, 9]
# X_train = train.drop([label], axis=1)
# X_test = test.drop([label], axis=1)
# y_train = train[[label]]
# y_test = test[[label]]

# %% [raw]
# dmatrix = xgb.DMatrix(data=X_train, label=y_train)
# params={ 'objective':'reg:squarederror',
#          'max_depth': 6,
#          'colsample_bylevel':0.5,
#          'learning_rate':0.01,
#          'random_state':20,
#         "tree_method":'gpu_hist'
#        }
# cv_results = xgb.cv(dtrain=dmatrix, params=params, nfold=10, metrics={'rmse'}, as_pandas=True, seed=20, num_boost_round=1000)
# print('RMSE: %.2f' % cv_results['test-rmse-mean'].min())

# %% [raw]
# import pandas as pd
# import numpy as np
# import xgboost as xgb
# from sklearn.model_selection import RandomizedSearchCV
#
# params = { 'max_depth': [3, 5, 6, 10, 15, 20],
#           'nthread':[4,8],
#            'learning_rate': [0.01, 0.1, 0.2, 0.3],
#            'subsample': np.arange(0.5, 1.0, 0.1),
#           'eval_metric':["mae","rmse"],
#            #'colsample_bytree': np.arange(0.4, 1.0, 0.1),
#            #'colsample_bylevel': np.arange(0.4, 1.0, 0.1),
#            'n_estimators': [100, 500, 1000],
#           'objective':["reg:squarederror","reg:pseudohubererror"],
#          "tree_method":['gpu_hist']}
# xgbr = xgb.XGBRegressor(seed = 20)
# clf = RandomizedSearchCV(estimator=xgbr,
#                          param_distributions=params,
#                          scoring='neg_mean_squared_error',
#                          n_iter=10,
#                          verbose=2)
# clf.fit(X_train, y_train)
# print("Best parameters:", clf.best_params_)
# print("Lowest RMSE: ", (-clf.best_score_)**(1/2.0))

# %%
train, test = train_test_split(data)

# %%
len(train),len(test)

# %%
pltlabel = "M/H"
dtest =  xgb.DMatrix(X_test, label=y_test)
xx = y_test.values.flatten()#.compute()
yy = model.predict(dtest).flatten()
lims = [-4, 0.7]
H,X,Y=np.histogram2d(xx, yy, bins=100,range=[lims, lims])
XX,YY=np.meshgrid(X,Y)
from scipy import ndimage
ax = plt.subplot(111)
Hg = ndimage.gaussian_filter(H,sigma=(0.7,0.7),order=0)
Hg[H<1] = np.NaN
image = ax.pcolor(XX, YY,Hg.T) #, cmap=cmaps[ii],norm=LogNorm(vmax=450),alpha=.5)
plt.xlabel('True Values ['+ pltlabel + ']', fontsize=18)
plt.ylabel('Predictions ['+ pltlabel + ']', fontsize=18)
plt.xlim(lims)
plt.ylim(lims)
plt.title(f"NStars: {len(xx)}")
plt.plot(lims, lims, c="grey", ls="dashed")

# %%
pltlabel = "Temp"
dtest =  xgb.DMatrix(X_test, label=y_test)
xx = y_test.values.flatten()#.compute()
yy = model.predict(dtest).flatten()
lims = [-4, 0.7]
H,X,Y=np.histogram2d(xx, yy, bins=100,range=[lims, lims])
XX,YY=np.meshgrid(X,Y)
from scipy import ndimage
ax = plt.subplot(111)
Hg = ndimage.gaussian_filter(H,sigma=(0.7,0.7),order=0)
Hg[H<1] = np.NaN
image = ax.pcolor(XX, YY,Hg.T) #, cmap=cmaps[ii],norm=LogNorm(vmax=450),alpha=.5)
plt.xlabel('True Values ['+ pltlabel + ']', fontsize=18)
plt.ylabel('Predictions ['+ pltlabel + ']', fontsize=18)
plt.xlim(lims)
plt.ylim(lims)
plt.title(f"NStars: {len(xx)}")
plt.plot(lims, lims, c="grey", ls="dashed")

# %%
dtest =  xgb.DMatrix(X_test, label=y_test)
y_pred = model.predict(dtest)
df_pred=pd.DataFrame({"x":y_test[label].values,"y":y_pred})
dflims=df_pred.describe().T
print(len(df_pred))
print(f"N Low Met={len(df_pred[df_pred.y<-1.5])}")
print(f"Should be N Low Met={len(df_pred[df_pred.x<-1.5])}")
img_fname=plot_one_prediction(df_pred,label,[-3.5,2.5],[-3.5,2.5])

# %%
dtest =  xgb.DMatrix(X_test, label=y_test)
y_pred = model.predict(dtest)
df_pred=pd.DataFrame({"x":y_test[label].values,"y":y_pred})
dflims=df_pred.describe().T
print(len(df_pred))
img_fname=plot_one_prediction(df_pred,label,[-2.5,2.5],[-2.5,2.5])

# %% [raw]
# from sklearn.multioutput import MultiOutputRegressor
# from sklearn.ensemble import GradientBoostingRegressor
# y_pred=MultiOutputRegressor(GradientBoostingRegressor(random_state=0)).fit(X_train, y_train).predict(X_train)

# %% [raw]
# df_pred=pd.DataFrame({"x":y_train[label].values,"y":y_pred})
# img_fname=plot_one_prediction(df_pred,label,[-2,2],[-2,2])

# %%
import umap

# %%
train, test = train_test_split(data)

# The predicted column is "quality" which is a scalar from [3, 9]
X_train = train.drop([label], axis=1)
X_test = test.drop([label], axis=1)
y_train = train[[label]]
y_test = test[[label]]

# %%
import umap.plot

mapper = umap.UMAP(n_neighbors=30,target_metric="L2",
                              min_dist=0.0,
                              n_components=2,
                              random_state=42).fit(X_train)#[X_test.columns[4:50]])
umap.plot.points(mapper)

# %%
import hyperopt
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import xgboost as xgb
train, test = train_test_split(data)

# The predicted column is "quality" which is a scalar from [3, 9]
if True:
    X_train = train.drop([label,"weights"], axis=1)
    X_test = test.drop([label,"weights"], axis=1)
    y_train = train[[label]]
    y_test = test[[label]]

# %%
import hyperopt as hp
from hyperopt import Trials,fmin,STATUS_OK
import xgboost as xgb


### Step 1 : defining the objective function
def objective(params, n_folds=3):

# Converting pandas dataframe into xgboost format
    d_train = xgb.DMatrix(X_train, y_train)    

# Running cross validation on your xgboost model
    cv_results = xgb.cv(params, d_train, nfold = n_folds, num_boost_round = 500, 
                        early_stopping_rounds = 25, metrics = 'rmse', seed = 42)
# returns the loss on validation set
    loss = min(cv_results['test-rmse-mean'])
    return loss


### step 2 : defining the search space
xgb_space = {
    'tree_method':"gpu_hist",
    "learning_rate":hp.hp.quniform('learning_rate',0.01,0.6,0.02),
#    max_depth : maximum depth allowed for every tree
# hp.choice.choice will select 1 value from the given list
    'max_depth':hp.hp.choice('max_depth', np.arange(6, 14,1, dtype=int)),
#    subsample : maximum allowed rows for every tree
    'subsample':hp.hp.quniform('subsample',0.5,1.0,0.05),
#    colsample_bytree : maximum allowed features for every tree
# hp.hp.quniform returns a float between a given range
#    'colsample_bytree':hp.hp.quniform('colsample_bytree',0.5,1.0,0.05),
#    min_child-weight : minimum number of instances required in each node
    'min_child_weight':hp.hp.quniform('min_child_weight', 1, 100,1),
    "objective":"reg:squarederror",
    "eval_metric":["mae","rmse"],
#    reg_alpha : L1 regularisation term on weights
#    'reg_alpha': hp.hp.uniform('reg_alpha', 0.0, 1.0),
#    reg_lambda : L2 regularisation term on weights
#    'reg_lambda': hp.hp.uniform('reg_lambda', 0.0, 1.0)
}
    
    
### step 3 : storing the results of every iteration    
bayes_trials = Trials()
MAX_EVALS = 20

# Optimize
best = fmin(fn = objective, space = xgb_space, algo = hp.tpe.suggest, 
max_evals = MAX_EVALS, trials = bayes_trials)

### best will the return the the best hyperparameter set
print(best)

# %%
train, test = train_test_split(data)

# The predicted column is "quality" which is a scalar from [3, 9]
if True:
    X_train = train.drop([label,"weights"], axis=1)
    X_test = test.drop([label,"weights"], axis=1)
    y_train = train[[label]]
    y_test = test[[label]]

# %%
import mlflow
# enable auto logging
mlflow.set_tracking_uri("http://localhost:5000")
logged_model = 'runs:/dcdf7dd33d1a4405afd718f52ce9a68e/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

y_pred=loaded_model.predict(pd.DataFrame(X_test))

# %%
df_pred=pd.DataFrame({"x":y_test[label].values,"y":y_pred})
dflims=df_pred.describe().T
print(len(df_pred))
img_fname=plot_one_prediction(df_pred,label,[-2.5,2.5],[-2.5,2.5])

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from xgboost_distribution import XGBDistribution


data = fetch_california_housing()
X, y = data.data, data.target
X_train, X_test, y_train, y_test = train_test_split(X, y)

model = XGBDistribution(
    distribution="normal",
    n_estimators=500,
    early_stopping_rounds=10
)
model.fit(X_train, y_train, eval_set=[(X_test, y_test)])

# %%
preds = model.predict(X_test)
mean, std = preds.loc, preds.scale

# %%
mean, std
